# %%
# Importing the necessary libraries

import numpy as np
import os

import datetime
import os
import warnings
warnings.filterwarnings("ignore")
import abc
from sys import getsizeof

# %%
from imageio import imread
from skimage.transform import resize
from PIL import Image

# %%
def imread(path):
    from PIL import Image
    return np.array(Image.open(path))

def imresize(img, size):
    from PIL import Image
    #return np.array(Image.fromarray(img).resize(size))
    return np.array(Image.fromarray((img * 255).astype(np.uint8)).resize(size))

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
# function to plot the training/validation accuracies/losses.

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [raw]
# %%bash
# eval "$(/mnt/disks/user/anaconda3/bin/conda shell.bash hook)"
# conda activate cuda101
# mamba install -c conda-forge --quiet -y opencv
# opencv config set -n proxy -v $HTTPS_PROXY

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# importing some other libraries which will be needed for model building.

from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers
from keras.layers import Dropout

# %%
project_folder='Project_data'

# %% [markdown]
# ##### Plotting

# %%
# function to plot the training/validation accuracies/losses.

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
class ModelBuilder(metaclass= abc.ABCMeta):
    # initialisng the path where project data resides
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
    # initialising the image properties    
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
    # initialising the batch size, frames to sample and the no. of epochs
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
    # generator function        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx):
                #performing image reading and resizing
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized= np.array(Image.fromarray((image*255).astype(np.uint8)).resize((self.image_width, self.image_height)).convert('RGB'))
                              #  np.array(Image.fromarray((img * 255).astype(np.uint8)).resize((input_size, input_size)).convert('RGB'))
                #image_resized=resize(image,(self.image_height,self.image_width,3))
            
                #normalizing the images
                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    # cropping the images to have the targeted gestures and remove the noise from the images.
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized= np.array(Image.fromarray((cropped*255).astype(np.uint8)).resize((self.image_width, self.image_height)).convert('RGB'))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])
    
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        
        earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
        callbacks_list = [checkpoint, LR, earlystop]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %% [markdown]
# ## 3D Convolution Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ## Model 1
# ### Base Model - Batch Size = 40 and No. of Epochs = 15

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=15)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 20, 160, 160, 16)  1312
# _________________________________________________________________
# activation (Activation)      (None, 20, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 20, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 10, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 10, 80, 80, 32)    13856
# _________________________________________________________________
# activation_1 (Activation)    (None, 10, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 5, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 5, 40, 40, 64)     55360
# _________________________________________________________________
# activation_2 (Activation)    (None, 5, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 2, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 2, 20, 20, 128)    221312
# _________________________________________________________________
# activation_3 (Activation)    (None, 2, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                819264
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,117,061
# Trainable params: 1,116,325
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1117061
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/15
# 17/17 [==============================] - 183s 10s/step - loss: 1.8896 - categorical_accuracy: 0.3383 - val_loss: 1.8406 - val_categorical_accuracy: 0.1600
#
# Epoch 00001: val_loss improved from inf to 1.84063, saving model to model_init_2021-08-0717_25_43.794851/model-00001-1.57398-0.42383-1.84063-0.16000.h5
# Epoch 2/15
# 17/17 [==============================] - 153s 9s/step - loss: 1.0514 - categorical_accuracy: 0.5654 - val_loss: 4.5378 - val_categorical_accuracy: 0.1500
#
# Epoch 00002: val_loss did not improve from 1.84063
# Epoch 3/15
# 17/17 [==============================] - 83s 5s/step - loss: 0.9307 - categorical_accuracy: 0.6049 - val_loss: 5.3379 - val_categorical_accuracy: 0.1700
#
# Epoch 00003: val_loss did not improve from 1.84063
# Epoch 4/15
# 17/17 [==============================] - 62s 4s/step - loss: 0.6435 - categorical_accuracy: 0.7689 - val_loss: 3.3628 - val_categorical_accuracy: 0.1600
#
# Epoch 00004: val_loss did not improve from 1.84063
# Epoch 5/15
# 17/17 [==============================] - 62s 4s/step - loss: 0.5108 - categorical_accuracy: 0.8306 - val_loss: 3.0339 - val_categorical_accuracy: 0.3000
#
# Epoch 00005: val_loss did not improve from 1.84063
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 6/15
# 17/17 [==============================] - 61s 4s/step - loss: 0.3763 - categorical_accuracy: 0.8692 - val_loss: 3.1754 - val_categorical_accuracy: 0.1900
#
# Epoch 00006: val_loss did not improve from 1.84063
# Epoch 7/15
# 17/17 [==============================] - 64s 4s/step - loss: 0.2982 - categorical_accuracy: 0.9159 - val_loss: 3.4040 - val_categorical_accuracy: 0.2100
#
# Epoch 00007: val_loss did not improve from 1.84063
# Epoch 8/15
# 17/17 [==============================] - 61s 4s/step - loss: 0.2801 - categorical_accuracy: 0.9437 - val_loss: 3.6816 - val_categorical_accuracy: 0.1800
#
# Epoch 00008: val_loss did not improve from 1.84063
# Epoch 9/15
# 17/17 [==============================] - 61s 4s/step - loss: 0.2310 - categorical_accuracy: 0.9398 - val_loss: 3.3836 - val_categorical_accuracy: 0.2400
#
# Epoch 00009: val_loss did not improve from 1.84063
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 10/15
# 17/17 [==============================] - 62s 4s/step - loss: 0.2317 - categorical_accuracy: 0.9480 - val_loss: 3.6802 - val_categorical_accuracy: 0.2100
#
# Epoch 00010: val_loss did not improve from 1.84063
# Epoch 11/15
# 17/17 [==============================] - 62s 4s/step - loss: 0.2102 - categorical_accuracy: 0.9562 - val_loss: 3.8661 - val_categorical_accuracy: 0.2100
#
# Epoch 00011: val_loss did not improve from 1.84063
# Epoch 00011: early stopping

# %%
plot(history_model1)

# %% [markdown]
# ##### It is a highly overfitting model.

# %% [markdown]
# ## Model 2
# ### Added dropout layers (50%) to above model

# %%
conv_3d2=ModelConv3D1()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=25)
conv_3d2_model=conv_3d2.define_model(dense_neurons=256,dropout=0.5)
conv_3d2_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 20, 160, 160, 16)  1312
# _________________________________________________________________
# activation (Activation)      (None, 20, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 20, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 10, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 10, 80, 80, 32)    13856
# _________________________________________________________________
# activation_1 (Activation)    (None, 10, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 5, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 5, 40, 40, 64)     55360
# _________________________________________________________________
# activation_2 (Activation)    (None, 5, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 2, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 2, 20, 20, 128)    221312
# _________________________________________________________________
# activation_3 (Activation)    (None, 2, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               3277056
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d2_model.count_params())
history_model2=conv_3d2.train_model(conv_3d2_model,augment_data=True)
# Out:
# Total Params: 3638981
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - 275s 8s/step - loss: 2.0717 - categorical_accuracy: 0.3551 - val_loss: 3.4385 - val_categorical_accuracy: 0.2100
#
# Epoch 00001: val_loss improved from inf to 3.43847, saving model to model_init_2021-08-0717_59_20.609162/model-00001-1.79749-0.40875-3.43847-0.21000.h5
# Epoch 2/25
# 34/34 [==============================] - 175s 5s/step - loss: 1.3274 - categorical_accuracy: 0.5330 - val_loss: 6.7596 - val_categorical_accuracy: 0.2300
#
# Epoch 00002: val_loss did not improve from 3.43847
# Epoch 3/25
# 34/34 [==============================] - 153s 5s/step - loss: 1.1482 - categorical_accuracy: 0.5837 - val_loss: 8.3062 - val_categorical_accuracy: 0.1900
#
# Epoch 00003: val_loss did not improve from 3.43847
# Epoch 4/25
# 34/34 [==============================] - 150s 5s/step - loss: 1.0091 - categorical_accuracy: 0.6505 - val_loss: 6.3621 - val_categorical_accuracy: 0.2700
#
# Epoch 00004: val_loss did not improve from 3.43847
# Epoch 5/25
# 34/34 [==============================] - 154s 5s/step - loss: 0.8353 - categorical_accuracy: 0.7018 - val_loss: 5.6926 - val_categorical_accuracy: 0.3000
#
# Epoch 00005: val_loss did not improve from 3.43847
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 6/25
# 34/34 [==============================] - 151s 5s/step - loss: 0.7291 - categorical_accuracy: 0.7160 - val_loss: 5.4027 - val_categorical_accuracy: 0.2600
#
# Epoch 00006: val_loss did not improve from 3.43847
# Epoch 7/25
# 34/34 [==============================] - 152s 5s/step - loss: 0.6502 - categorical_accuracy: 0.7545 - val_loss: 4.7549 - val_categorical_accuracy: 0.2600
#
# Epoch 00007: val_loss did not improve from 3.43847
# Epoch 8/25
# 34/34 [==============================] - 154s 5s/step - loss: 0.5588 - categorical_accuracy: 0.7985 - val_loss: 4.8671 - val_categorical_accuracy: 0.2700
#
# Epoch 00008: val_loss did not improve from 3.43847
# Epoch 9/25
# 34/34 [==============================] - 151s 5s/step - loss: 0.6271 - categorical_accuracy: 0.7806 - val_loss: 5.3793 - val_categorical_accuracy: 0.2400
#
# Epoch 00009: val_loss did not improve from 3.43847
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 10/25
# 34/34 [==============================] - 153s 5s/step - loss: 0.4941 - categorical_accuracy: 0.8120 - val_loss: 3.9273 - val_categorical_accuracy: 0.3600
#
# Epoch 00010: val_loss did not improve from 3.43847
# Epoch 11/25
# 34/34 [==============================] - 152s 5s/step - loss: 0.4607 - categorical_accuracy: 0.8158 - val_loss: 3.4600 - val_categorical_accuracy: 0.3600
#
# Epoch 00011: val_loss did not improve from 3.43847
# Epoch 00011: early stopping

# %%
plot(history_model2)

# %% [markdown]
# ##### There is a slight improvement in the validation accuracy from the previos model. As validation loss did not improve early spopping happened.
# - validation accuracy is 36%

# %% [markdown]
# ## Model 3
# ### Trying to reduce the filter size to (2,2,2) and image res to 120 x  120

# %%
class ModelConv3D3(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))
        
        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d3=ModelConv3D3()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=120,image_width=120)
conv_3d3.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d3_model=conv_3d3.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d3_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_4 (Conv3D)            (None, 16, 120, 120, 16)  400
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 8, 60, 60, 32)     4128
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 4, 30, 30, 64)     16448
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 2, 15, 15, 128)    65664
# _________________________________________________________________
# activation_7 (Activation)    (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               1605888
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 1,762,613
# Trainable params: 1,761,109
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d3_model.count_params())
history_model3=conv_3d3.train_model(conv_3d3_model,augment_data=True)
# Out:
# Total Params: 1762613
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 23/23 [==============================] - 165s 7s/step - loss: 2.3660 - categorical_accuracy: 0.2965 - val_loss: 1.7759 - val_categorical_accuracy: 0.2100
#
# Epoch 00001: val_loss improved from inf to 1.77591, saving model to model_init_2021-08-0718_31_30.825433/model-00001-2.08772-0.34917-1.77591-0.21000.h5
# Epoch 2/25
# 23/23 [==============================] - 132s 6s/step - loss: 1.5059 - categorical_accuracy: 0.4795 - val_loss: 2.4763 - val_categorical_accuracy: 0.1200
#
# Epoch 00002: val_loss did not improve from 1.77591
# Epoch 3/25
# 23/23 [==============================] - 104s 5s/step - loss: 1.2424 - categorical_accuracy: 0.5703 - val_loss: 3.2737 - val_categorical_accuracy: 0.2100
#
# Epoch 00003: val_loss did not improve from 1.77591
# Epoch 4/25
# 23/23 [==============================] - 104s 5s/step - loss: 1.0731 - categorical_accuracy: 0.6147 - val_loss: 4.0053 - val_categorical_accuracy: 0.2100
#
# Epoch 00004: val_loss did not improve from 1.77591
# Epoch 5/25
# 23/23 [==============================] - 102s 5s/step - loss: 0.9567 - categorical_accuracy: 0.6614 - val_loss: 4.6665 - val_categorical_accuracy: 0.2100
#
# Epoch 00005: val_loss did not improve from 1.77591
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# Epoch 6/25
# 23/23 [==============================] - 104s 5s/step - loss: 0.9964 - categorical_accuracy: 0.6541 - val_loss: 5.3290 - val_categorical_accuracy: 0.1500
#
# Epoch 00006: val_loss did not improve from 1.77591
# Epoch 7/25
# 23/23 [==============================] - 102s 5s/step - loss: 0.8752 - categorical_accuracy: 0.6681 - val_loss: 5.6359 - val_categorical_accuracy: 0.2200
#
# Epoch 00007: val_loss did not improve from 1.77591
# Epoch 8/25
# 23/23 [==============================] - 127s 6s/step - loss: 0.8268 - categorical_accuracy: 0.7137 - val_loss: 5.8120 - val_categorical_accuracy: 0.2200
#
# Epoch 00008: val_loss did not improve from 1.77591
# Epoch 9/25
# 23/23 [==============================] - 105s 5s/step - loss: 0.8514 - categorical_accuracy: 0.6874 - val_loss: 5.9068 - val_categorical_accuracy: 0.2700
#
# Epoch 00009: val_loss did not improve from 1.77591
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# Epoch 10/25
# 23/23 [==============================] - 101s 5s/step - loss: 0.8432 - categorical_accuracy: 0.6811 - val_loss: 5.9431 - val_categorical_accuracy: 0.2600
#
# Epoch 00010: val_loss did not improve from 1.77591
# Epoch 11/25
# 23/23 [==============================] - 103s 5s/step - loss: 0.7943 - categorical_accuracy: 0.7263 - val_loss: 5.7816 - val_categorical_accuracy: 0.2400
#
# Epoch 00011: val_loss did not improve from 1.77591
# Epoch 00011: early stopping

# %%
plot(history_model3)

# %% [markdown]
# ##### The model's validation accuracy has not improved. Trying to add more layers to see the result

# %% [markdown]
# ## Model 4 -
# ### Adding more layers

# %%
class ModelConv3D4(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d4=ModelConv3D4()
conv_3d4.initialize_path(project_folder)
conv_3d4.initialize_image_properties(image_height=120,image_width=120)
conv_3d4.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d4_model=conv_3d4.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.5)
conv_3d4_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 16, 120, 120, 16)  1312
# _________________________________________________________________
# activation (Activation)      (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 16, 120, 120, 16)  6928
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 8, 60, 60, 32)     13856
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 8, 60, 60, 32)     27680
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 4, 30, 30, 64)     55360
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 4, 30, 30, 64)     110656
# _________________________________________________________________
# activation_5 (Activation)    (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 2, 15, 15, 128)    221312
# _________________________________________________________________
# activation_6 (Activation)    (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 2, 15, 15, 128)    442496
# _________________________________________________________________
# activation_7 (Activation)    (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1605888
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 2,556,533
# Trainable params: 2,554,549
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
print("Total Params:", conv_3d4_model.count_params())
history_model4=conv_3d4.train_model(conv_3d4_model,augment_data=True)
# Out:
# Total Params: 2556533
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - 140s 4s/step - loss: 2.3133 - categorical_accuracy: 0.2725 - val_loss: 2.4815 - val_categorical_accuracy: 0.2100
#
# Epoch 00001: val_loss improved from inf to 2.48147, saving model to model_init_2021-08-0815_15_31.251197/model-00001-2.04181-0.31976-2.48147-0.21000.h5
# Epoch 2/25
# 34/34 [==============================] - 112s 3s/step - loss: 1.5423 - categorical_accuracy: 0.4462 - val_loss: 4.7136 - val_categorical_accuracy: 0.1700
#
# Epoch 00002: val_loss did not improve from 2.48147
# Epoch 3/25
# 34/34 [==============================] - 109s 3s/step - loss: 1.3704 - categorical_accuracy: 0.4934 - val_loss: 5.0599 - val_categorical_accuracy: 0.1800
#
# Epoch 00003: val_loss did not improve from 2.48147
# Epoch 4/25
# 34/34 [==============================] - 112s 3s/step - loss: 1.2977 - categorical_accuracy: 0.5041 - val_loss: 4.9650 - val_categorical_accuracy: 0.2100
#
# Epoch 00004: val_loss did not improve from 2.48147
# Epoch 5/25
# 34/34 [==============================] - 110s 3s/step - loss: 1.1343 - categorical_accuracy: 0.5845 - val_loss: 4.2529 - val_categorical_accuracy: 0.2000
#
# Epoch 00005: val_loss did not improve from 2.48147
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 6/25
# 34/34 [==============================] - 113s 3s/step - loss: 1.1076 - categorical_accuracy: 0.5877 - val_loss: 5.3539 - val_categorical_accuracy: 0.2100
#
# Epoch 00006: val_loss did not improve from 2.48147
# Epoch 7/25
# 34/34 [==============================] - 111s 3s/step - loss: 0.8851 - categorical_accuracy: 0.6743 - val_loss: 3.6854 - val_categorical_accuracy: 0.3000
#
# Epoch 00007: val_loss did not improve from 2.48147
# Epoch 8/25
# 34/34 [==============================] - 110s 3s/step - loss: 0.8840 - categorical_accuracy: 0.6709 - val_loss: 3.3563 - val_categorical_accuracy: 0.1800
#
# Epoch 00008: val_loss did not improve from 2.48147
# Epoch 9/25
# 34/34 [==============================] - 109s 3s/step - loss: 0.8061 - categorical_accuracy: 0.6848 - val_loss: 2.4829 - val_categorical_accuracy: 0.2300
#
# Epoch 00009: val_loss did not improve from 2.48147
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 10/25
# 34/34 [==============================] - 111s 3s/step - loss: 0.7264 - categorical_accuracy: 0.7269 - val_loss: 2.6820 - val_categorical_accuracy: 0.2900
#
# Epoch 00010: val_loss did not improve from 2.48147
# Epoch 11/25
# 34/34 [==============================] - 108s 3s/step - loss: 0.8486 - categorical_accuracy: 0.6656 - val_loss: 2.3940 - val_categorical_accuracy: 0.3100
#
# Epoch 00011: val_loss improved from 2.48147 to 2.39398, saving model to model_init_2021-08-0815_15_31.251197/model-00011-0.78395-0.69080-2.39398-0.31000.h5
# Epoch 12/25
# 34/34 [==============================] - 110s 3s/step - loss: 0.7518 - categorical_accuracy: 0.6952 - val_loss: 2.2812 - val_categorical_accuracy: 0.3200
#
# Epoch 00012: val_loss improved from 2.39398 to 2.28117, saving model to model_init_2021-08-0815_15_31.251197/model-00012-0.75056-0.69985-2.28117-0.32000.h5
# Epoch 13/25
# 34/34 [==============================] - 110s 3s/step - loss: 0.7076 - categorical_accuracy: 0.7363 - val_loss: 1.7912 - val_categorical_accuracy: 0.4400
#
# Epoch 00013: val_loss improved from 2.28117 to 1.79116, saving model to model_init_2021-08-0815_15_31.251197/model-00013-0.69281-0.73454-1.79116-0.44000.h5
# Epoch 14/25
# 34/34 [==============================] - 111s 3s/step - loss: 0.6872 - categorical_accuracy: 0.7393 - val_loss: 1.5925 - val_categorical_accuracy: 0.4400
#
# Epoch 00014: val_loss improved from 1.79116 to 1.59248, saving model to model_init_2021-08-0815_15_31.251197/model-00014-0.71402-0.73152-1.59248-0.44000.h5
# Epoch 15/25
# 34/34 [==============================] - 108s 3s/step - loss: 0.7626 - categorical_accuracy: 0.7282 - val_loss: 1.4792 - val_categorical_accuracy: 0.5100
#
# Epoch 00015: val_loss improved from 1.59248 to 1.47923, saving model to model_init_2021-08-0815_15_31.251197/model-00015-0.73310-0.73379-1.47923-0.51000.h5
# Epoch 16/25
# 34/34 [==============================] - 110s 3s/step - loss: 0.6589 - categorical_accuracy: 0.7387 - val_loss: 1.1596 - val_categorical_accuracy: 0.5800
#
# Epoch 00016: val_loss improved from 1.47923 to 1.15963, saving model to model_init_2021-08-0815_15_31.251197/model-00016-0.66556-0.74736-1.15963-0.58000.h5
# Epoch 17/25
# 34/34 [==============================] - 110s 3s/step - loss: 0.6424 - categorical_accuracy: 0.7557 - val_loss: 1.0624 - val_categorical_accuracy: 0.5800
#
# Epoch 00017: val_loss improved from 1.15963 to 1.06239, saving model to model_init_2021-08-0815_15_31.251197/model-00017-0.64305-0.75339-1.06239-0.58000.h5
# Epoch 18/25
# 34/34 [==============================] - 110s 3s/step - loss: 0.6549 - categorical_accuracy: 0.7483 - val_loss: 0.9107 - val_categorical_accuracy: 0.6400
#
# Epoch 00018: val_loss improved from 1.06239 to 0.91067, saving model to model_init_2021-08-0815_15_31.251197/model-00018-0.66360-0.75189-0.91067-0.64000.h5
# Epoch 19/25
# 34/34 [==============================] - 109s 3s/step - loss: 0.6719 - categorical_accuracy: 0.7378 - val_loss: 0.7521 - val_categorical_accuracy: 0.7000
#
# Epoch 00019: val_loss improved from 0.91067 to 0.75211, saving model to model_init_2021-08-0815_15_31.251197/model-00019-0.71732-0.71795-0.75211-0.70000.h5
# Epoch 20/25
# 34/34 [==============================] - 109s 3s/step - loss: 0.5826 - categorical_accuracy: 0.7601 - val_loss: 0.7260 - val_categorical_accuracy: 0.6900
#
# Epoch 00020: val_loss improved from 0.75211 to 0.72595, saving model to model_init_2021-08-0815_15_31.251197/model-00020-0.60931-0.75792-0.72595-0.69000.h5
# Epoch 21/25
# 34/34 [==============================] - 108s 3s/step - loss: 0.6657 - categorical_accuracy: 0.7430 - val_loss: 0.6898 - val_categorical_accuracy: 0.6800
#
# Epoch 00021: val_loss improved from 0.72595 to 0.68978, saving model to model_init_2021-08-0815_15_31.251197/model-00021-0.68868-0.73529-0.68978-0.68000.h5
# Epoch 22/25
# 34/34 [==============================] - 112s 3s/step - loss: 0.6217 - categorical_accuracy: 0.7691 - val_loss: 0.6131 - val_categorical_accuracy: 0.7400
#
# Epoch 00022: val_loss improved from 0.68978 to 0.61307, saving model to model_init_2021-08-0815_15_31.251197/model-00022-0.64565-0.75113-0.61307-0.74000.h5
# Epoch 23/25
# 34/34 [==============================] - 108s 3s/step - loss: 0.6244 - categorical_accuracy: 0.7559 - val_loss: 0.6866 - val_categorical_accuracy: 0.7200
#
# Epoch 00023: val_loss did not improve from 0.61307
# Epoch 24/25
# 34/34 [==============================] - 110s 3s/step - loss: 0.5237 - categorical_accuracy: 0.7963 - val_loss: 0.5884 - val_categorical_accuracy: 0.7500
#
# Epoch 00024: val_loss improved from 0.61307 to 0.58842, saving model to model_init_2021-08-0815_15_31.251197/model-00024-0.57172-0.77828-0.58842-0.75000.h5
# Epoch 25/25
# 34/34 [==============================] - 109s 3s/step - loss: 0.5547 - categorical_accuracy: 0.7875 - val_loss: 0.6667 - val_categorical_accuracy: 0.7600
#
# Epoch 00025: val_loss did not improve from 0.58842

# %%
plot(history_model4)

# %% [markdown]
# ##### This seems to be a better model so far as train accuracy is 78% and test acuracy is 76%

# %% [markdown]
# ### Model 5

# %%
class ModelConv3D5(ModelBuilder):
    
    def define_model(self,filtersize=(2,2,2),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d5=ModelConv3D5()
conv_3d5.initialize_path(project_folder)
conv_3d5.initialize_image_properties(image_height=120,image_width=120)
conv_3d5.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d5_model=conv_3d5.define_model(dense_neurons=64,dropout=0.25)
conv_3d5_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_8 (Conv3D)            (None, 16, 120, 120, 16)  400
# _________________________________________________________________
# activation_8 (Activation)    (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 16, 120, 120, 16)  2064
# _________________________________________________________________
# activation_9 (Activation)    (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 8, 60, 60, 32)     4128
# _________________________________________________________________
# activation_10 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 8, 60, 60, 32)     8224
# _________________________________________________________________
# activation_11 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_12 (Conv3D)           (None, 4, 30, 30, 64)     16448
# _________________________________________________________________
# activation_12 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# conv3d_13 (Conv3D)           (None, 4, 30, 30, 64)     32832
# _________________________________________________________________
# activation_13 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_14 (Conv3D)           (None, 2, 15, 15, 128)    65664
# _________________________________________________________________
# activation_14 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# conv3d_15 (Conv3D)           (None, 2, 15, 15, 128)    131200
# _________________________________________________________________
# activation_15 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                401472
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 669,349
# Trainable params: 668,133
# Non-trainable params: 1,216
# _________________________________________________________________

# %%
print("Total Params:", conv_3d5_model.count_params())
history_model5=conv_3d5.train_model(conv_3d5_model,augment_data=True)
# Out:
# Total Params: 669349
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - 222s 6s/step - loss: 1.7754 - categorical_accuracy: 0.3517 - val_loss: 2.2315 - val_categorical_accuracy: 0.2100
#
# Epoch 00001: val_loss improved from inf to 2.23153, saving model to model_init_2021-08-0817_06_19.812304/model-00001-1.50046-0.44118-2.23153-0.21000.h5
# Epoch 2/25
# 34/34 [==============================] - 187s 6s/step - loss: 1.1610 - categorical_accuracy: 0.5491 - val_loss: 2.3664 - val_categorical_accuracy: 0.1700
#
# Epoch 00002: val_loss did not improve from 2.23153
# Epoch 3/25
# 34/34 [==============================] - 157s 5s/step - loss: 0.8832 - categorical_accuracy: 0.6486 - val_loss: 2.7301 - val_categorical_accuracy: 0.2100
#
# Epoch 00003: val_loss did not improve from 2.23153
# Epoch 4/25
# 34/34 [==============================] - 130s 4s/step - loss: 0.7628 - categorical_accuracy: 0.6937 - val_loss: 3.9130 - val_categorical_accuracy: 0.1900
#
# Epoch 00004: val_loss did not improve from 2.23153
# Epoch 5/25
# 34/34 [==============================] - 121s 4s/step - loss: 0.6273 - categorical_accuracy: 0.7617 - val_loss: 5.0310 - val_categorical_accuracy: 0.1900
#
# Epoch 00005: val_loss did not improve from 2.23153
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 6/25
# 34/34 [==============================] - 123s 4s/step - loss: 0.5514 - categorical_accuracy: 0.7868 - val_loss: 4.9023 - val_categorical_accuracy: 0.2200
#
# Epoch 00006: val_loss did not improve from 2.23153
# Epoch 7/25
# 34/34 [==============================] - 122s 4s/step - loss: 0.5071 - categorical_accuracy: 0.8204 - val_loss: 4.9559 - val_categorical_accuracy: 0.2200
#
# Epoch 00007: val_loss did not improve from 2.23153
# Epoch 8/25
# 34/34 [==============================] - 121s 4s/step - loss: 0.4079 - categorical_accuracy: 0.8642 - val_loss: 4.9744 - val_categorical_accuracy: 0.2400
#
# Epoch 00008: val_loss did not improve from 2.23153
# Epoch 9/25
# 34/34 [==============================] - 122s 4s/step - loss: 0.4606 - categorical_accuracy: 0.8365 - val_loss: 5.2754 - val_categorical_accuracy: 0.2100
#
# Epoch 00009: val_loss did not improve from 2.23153
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 10/25
# 34/34 [==============================] - 116s 4s/step - loss: 0.3246 - categorical_accuracy: 0.8939 - val_loss: 4.7434 - val_categorical_accuracy: 0.2000
#
# Epoch 00010: val_loss did not improve from 2.23153
# Epoch 11/25
# 34/34 [==============================] - 122s 4s/step - loss: 0.3794 - categorical_accuracy: 0.8647 - val_loss: 4.0073 - val_categorical_accuracy: 0.3000
#
# Epoch 00011: val_loss did not improve from 2.23153
# Epoch 00011: early stopping

# %%
plot(history_model5)

# %% [markdown]
# #### Reducing the filter size not benefit this time. We will keep the previous model.(Model 4)
